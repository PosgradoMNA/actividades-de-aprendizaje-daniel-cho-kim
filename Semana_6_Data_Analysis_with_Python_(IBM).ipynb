# %% [markdown]
# # **Semana 6: Data Analysis with Python (IBM)**
# ## **Práctica de aprendizaje**
#
#
# 1.   Módulo 3 - Exploratory Data Analysis

# %% [markdown]
# ----
# ## Lab 3
# ### Question 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ### Question 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ### Question 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ### Question 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ## Graded Review Questions

# %% [markdown]
# ![image.png](data:image/png;base64,...)
