# %% [markdown]
# # **Semana 2 - Actividad 1: Python for Data Science (IBM)**
# ## **Práctica de aprendizaje**
#
#
# 1.   Módulo 4 - Working with Data in Python

# %% [markdown]
# ----
# ## **Módulo 4 - Working with Data in Python**
#
# 1.   Reading files with open
# 2.   Writing files with open
# 3.   Loading data with Pandas
# 4.   Working with and Saving Data with Pandas

# %% [markdown]
# ---
# ## 1. Reading files with open (LAB)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## 2. Write files with open (LAB)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## 3. Lab - Loading Data and Viewing Data (LAB)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
