# %% [markdown]
# # **Semana 8: Data Analysis with Python (IBM)**
# ## **Práctica de aprendizaje**
#
#
# 1.   Módulo 5 - Model Evaluation

# %% [markdown]
# ----
# ## Lab 5
# ### Question 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ### Question 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ### Question 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ### Question 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ### Question 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ## Graded Review Questions

# %% [markdown]
# ![image.png](data:image/png;base64,...)
