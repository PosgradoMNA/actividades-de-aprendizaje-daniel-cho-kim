# %% [markdown]
# # **Semana 3 - Python for Data Science (IBM)**
# ## **Práctica de aprendizaje**
#
#
# 1.   Módulo 5 - Working with Numpy Arrays & Simple APIs

# %% [markdown]
# ----
# ## **Módulo 5 - Working with Numpy Arrays & Simple APIs**
#
# 1.   Numpy 1D arrays
# 2.   Numpy 2D arrays
# 3.   Simple APIs 1
# 4.   Simple APIs 2

# %% [markdown]
# ---
# ## 1. Working with 1D Numpy Arrays (LAB)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## 2. Working with 2D Numpy Arrays (LAB)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## 3. HTTP and Requests (LAB)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## 4. API (Lab)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## Review Questions
# ![image.png](data:image/png;base64,...)
