# %% [markdown]
# # **Semana 5: Data Analysis with Python (IBM)**
# ## **Práctica de aprendizaje**
#
#
# 1.   Módulo 2 - Data Wrangling

# %% [markdown]
# ----
# ## Lab 2
# ### Question 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ### Question 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ### Question 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ### Question 4 & 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ----
# ## Graded Review Questions

# %% [markdown]
# ![image.png](data:image/png;base64,...)
